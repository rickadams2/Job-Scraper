# %%
from IndeedScraper import IndeedScraper
import pandas as pd

scraper = IndeedScraper("software", "san francisco bay area")
display(scraper.data)
# Out:
# Created 15 job objects.
# Done
#                                                 Title             Company  \
# 0   newStrategy & Business Modeling Business Analy...                 BTS
# 1   newSenior/Staff Product Designer, Admin Experi...                Okta
# 2                                newSoftware Engineer          Comcentric
# 3   newStaff Backend Engineer - Activision Blizzar...            King.com
# 4                      newSenior JavaScript Developer           ViacomCBS
# 5                      newSenior JavaScript Developer          Paramount+
# 6     newGroup Product Manager, Universal Directories                Okta
# 7                      newDevOps Cloud Engineer - Tax            Deloitte
# 8                              newStaff Data Engineer            King.com
# 9                                newLead UI Developer         Wells Fargo
# 10         newMgr, Software Development & Engineering      Charles Schwab
# 11                   newMaster Software Engineer, iOS    Capital One - US
# 12                 newTechnical Program Manager (TPM)                Uber
# 13      newFull-Stack Engineer, Data Science - Remote            RunBuggy
# 14                       newUX Designer, Monetization  PlayStation Global
#
#                                                  Link               Date
# 0                 https://indeed.com/cmp/Bts-5692bccb  PostedJust posted
# 1                         https://indeed.com/cmp/Okta  PostedJust posted
# 2                   https://indeed.com/cmp/Comcentric  PostedJust posted
# 3   https://indeed.com/q-King-Com-l-Foster-City,-C...  PostedJust posted
# 4                    https://indeed.com/cmp/Viacomcbs  PostedJust posted
# 5   https://indeed.com/q-Paramount+-l-San-Francisc...  PostedJust posted
# 6                         https://indeed.com/cmp/Okta  PostedJust posted
# 7                     https://indeed.com/cmp/Deloitte  PostedJust posted
# 8   https://indeed.com/q-King-Com-l-Foster-City,-C...  PostedJust posted
# 9                  https://indeed.com/cmp/Wells-Fargo  PostedJust posted
# 10              https://indeed.com/cmp/Charles-Schwab        PostedToday
# 11                 https://indeed.com/cmp/Capital-One        PostedToday
# 12                        https://indeed.com/cmp/Uber        PostedToday
# 13  https://indeed.com/q-Runbuggy-l-San-Francisco,...        PostedToday
# 14  https://indeed.com/addlLoc/redirect?tk=1fpghks...        PostedToday
