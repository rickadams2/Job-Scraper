# %%
from IndeedScraper import IndeedScraper
import pandas as pd

scraper = IndeedScraper("software", "San Francisco, CA")
old_df = pd.read_excel('job-data.xlsx')
new_df = pd.concat([scraper.data, old_df], ignore_index = True)
new_df.drop(new_df.columns[[4]], axis=1, inplace=True) 
display(new_df)
#new_df.to_excel('job-data.xlsx')
# Out:
# https://www.indeed.com/jobs?q=software&l=San+Francisco%2C+CA&radius=15&explvl=entry_level&sort=date&limit=50&fromage=last
# ...
